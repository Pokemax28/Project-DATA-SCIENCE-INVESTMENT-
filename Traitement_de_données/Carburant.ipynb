# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)  


Carburant = pd.read_csv(
    '../Data/Carburant.csv',
    sep=';',          # try also ',' if this doesn't work
    on_bad_lines='skip',  # skips problematic lines
    engine='python'       # slower but more flexible
)

Carburant.head(5)
# Out:
#          id   latitude  longitude  Code postal pop                  Adresse  \
# 0  21230005  4713100.0   449000.0        21230   R       Rue de l'Arquebuse
# 1  37210004  4741200.0    80300.0        37210   R        27 Rue des Écoles
# 2  46200004  4489900.0   147500.0        46200   R      51 rue de la Récège
# 3  33290001  4494839.0   -63068.0        33290   R        Route de Pauillac
# 4  12400003  4395400.0   285000.0        12400   R  Route de Saint-Affrique
#
#              Ville                                           services  \
# 0     Arnay-le-Duc  {"service": ["Boutique alimentaire", "Boutique...
# 1          Vouvray  {"service": ["Laverie", "Relais colis", "Bouti...
# 2         Souillac  {"service": ["Laverie", "Relais colis", "Bouti...
# 3    Le Pian-Médoc  {"service": ["Toilettes publiques", "Boutique ...
# 4  Vabres-l'Abbaye  {"service": ["Toilettes publiques", "Laverie",...
#
#                                                 prix  \
# 0  [{"@nom": "Gazole", "@id": "1", "@maj": "2025-...
# 1  [{"@nom": "Gazole", "@id": "1", "@maj": "2025-...
# 2  [{"@nom": "Gazole", "@id": "1", "@maj": "2025-...
# 3  [{"@nom": "Gazole", "@id": "1", "@maj": "2025-...
# 4  [{"@nom": "Gazole", "@id": "1", "@maj": "2025-...
#
#                                              rupture  \
# 0  [{"@nom": "E85", "@id": "3", "@debut": "2024-1...
# 1  [{"@nom": "E85", "@id": "3", "@debut": "2022-1...
# 2  [{"@nom": "SP95", "@id": "2", "@debut": "2024-...
# 3  [{"@nom": "GPLc", "@id": "4", "@debut": "2017-...
# 4  [{"@nom": "GPLc", "@id": "4", "@debut": "2018-...
#
#                                             horaires                geom  \
# 0                                                NaN        47.131, 4.49
# 1  {"@automate-24-24": "1", "jour": [{"@id": "1",...       47.412, 0.803
# 2  {"@automate-24-24": "1", "jour": [{"@id": "1",...       44.899, 1.475
# 3                                                NaN  44.94839, -0.63068
# 4  {"@automate-24-24": "1", "jour": [{"@id": "1",...        43.954, 2.85
#
#    Prix Gazole mis à jour le  Prix Gazole    Prix SP95 mis à jour le  \
# 0  2025-10-13T09:09:39+00:00        1.629  2025-10-13T09:09:39+00:00
# 1  2025-08-26T10:15:00+00:00        1.598  2025-08-26T10:15:00+00:00
# 2  2025-08-25T18:02:34+00:00        1.599                        NaN
# 3  2025-10-15T22:41:00+00:00        1.559                        NaN
# 4  2025-10-11T09:45:22+00:00        1.579  2025-10-11T09:45:22+00:00
#
#    Prix SP95     Prix E85 mis à jour le  Prix E85 Prix GPLc mis à jour le  \
# 0      1.729                        NaN       NaN                     NaN
# 1      1.756                        NaN       NaN                     NaN
# 2        NaN  2025-08-25T18:02:34+00:00     0.688                     NaN
# 3        NaN  2025-10-15T22:41:00+00:00     0.739                     NaN
# 4      1.719  2025-10-11T09:45:22+00:00     0.688                     NaN
#
#    Prix GPLc     Prix E10 mis à jour le  Prix E10    Prix SP98 mis à jour le  \
# 0        NaN                        NaN       NaN  2025-10-13T09:09:39+00:00
# 1        NaN                        NaN       NaN  2025-08-26T10:15:00+00:00
# 2        NaN  2025-08-25T18:02:34+00:00     1.669                        NaN
# 3        NaN  2025-10-15T22:41:00+00:00     1.632  2025-10-15T22:41:00+00:00
# 4        NaN  2025-10-11T09:45:22+00:00     1.636                        NaN
#
#    Prix SP98 Début rupture e10 (si temporaire) Type rupture e10  \
# 0      1.809         2019-10-25T15:45:03+00:00       definitive
# 1      1.767         2022-10-10T22:30:49+00:00       definitive
# 2        NaN                               NaN              NaN
# 3      1.735                               NaN              NaN
# 4        NaN                               NaN              NaN
#
#   Début rupture sp98 (si temporaire) Type rupture sp98  \
# 0                                NaN               NaN
# 1                                NaN               NaN
# 2          2024-07-04T09:45:05+00:00        definitive
# 3                                NaN               NaN
# 4          2018-11-09T11:11:53+00:00        definitive
#
#   Début rupture sp95 (si temporaire) Type rupture sp95  \
# 0                                NaN               NaN
# 1                                NaN               NaN
# 2          2024-07-04T09:45:05+00:00        definitive
# 3          2025-06-13T20:16:14+00:00        definitive
# 4                                NaN               NaN
#
#   Début rupture e85 (si temporaire) Type rupture e85  \
# 0         2024-10-05T07:29:42+00:00       definitive
# 1         2022-10-10T22:30:49+00:00       definitive
# 2                               NaN              NaN
# 3                               NaN              NaN
# 4                               NaN              NaN
#
#   Début rupture GPLc (si temporaire) Type rupture GPLc  \
# 0          2024-10-05T07:30:13+00:00        definitive
# 1          2022-10-10T22:30:49+00:00        definitive
# 2          2025-01-03T14:44:47+00:00        definitive
# 3          2017-09-01T18:47:17+00:00        definitive
# 4          2018-11-09T11:11:53+00:00        definitive
#
#   Début rupture gazole (si temporaire) Type rupture gazole  \
# 0                                  NaN                 NaN
# 1                                  NaN                 NaN
# 2                                  NaN                 NaN
# 3                                  NaN                 NaN
# 4                                  NaN                 NaN
#
#   Carburants disponibles Carburants indisponibles  \
# 0       Gazole,SP95,SP98             E85,GPLc,E10
# 1       Gazole,SP95,SP98             E85,GPLc,E10
# 2         Gazole,E85,E10           SP95,GPLc,SP98
# 3    Gazole,E85,E10,SP98                SP95,GPLc
# 4    Gazole,SP95,E85,E10                GPLc,SP98
#
#   Carburants en rupture temporaire Carburants en rupture definitive  \
# 0                              NaN                     E85;GPLc;E10
# 1                              NaN                     E85;GPLc;E10
# 2                              NaN                   SP95;GPLc;SP98
# 3                              NaN                        SP95;GPLc
# 4                              NaN                        GPLc;SP98
#
#   Automate 24-24 (oui/non)                                  Services proposés  \
# 0                      Non  Boutique alimentaire,Boutique non alimentaire,...
# 1                      Oui  Laverie,Relais colis,Boutique alimentaire,Bout...
# 2                      Oui  Laverie,Relais colis,Boutique alimentaire,Bout...
# 3                      Non  Toilettes publiques,Boutique alimentaire,Bouti...
# 4                      Oui  Toilettes publiques,Laverie,Boutique alimentai...
#
#       Département code_departement                   Région  code_region  \
# 0       Côte-d'Or               21  Bourgogne-Franche-Comté         27.0
# 1  Indre-et-Loire               37      Centre-Val de Loire         24.0
# 2             Lot               46                Occitanie         76.0
# 3         Gironde               33       Nouvelle-Aquitaine         75.0
# 4         Aveyron               12                Occitanie         76.0
#
#                                   horaires détaillés
# 0                                                NaN
# 1  Automate-24-24, Lundi 09.00-12.00 et 15.30-19....
# 2                                     Automate-24-24
# 3                                                NaN
# 4  Automate-24-24, Lundi00.00-23.59, Mardi00.00-2...

# %%
# Cleaning column names
Carburant.columns = Carburant.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
Carburant.info()
Carburant.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10023 entries, 0 to 10022
# Data columns (total 47 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  10023 non-null  int64
#  1   latitude                            10023 non-null  float64
#  2   longitude                           10023 non-null  float64
#  3   code_postal                         10023 non-null  int64
#  4   pop                                 10023 non-null  object
#  5   adresse                             10022 non-null  object
#  6   ville                               10019 non-null  object
#  7   services                            9273 non-null   object
#  8   prix                                9675 non-null   object
#  9   rupture                             9115 non-null   object
#  10  horaires                            8254 non-null   object
#  11  geom                                10023 non-null  object
#  12  prix_gazole_mis_à_jour_le           9635 non-null   object
#  13  prix_gazole                         9635 non-null   float64
#  14  prix_sp95_mis_à_jour_le             3258 non-null   object
#  15  prix_sp95                           3258 non-null   float64
#  16  prix_e85_mis_à_jour_le              3847 non-null   object
#  17  prix_e85                            3847 non-null   float64
#  18  prix_gplc_mis_à_jour_le             1446 non-null   object
#  19  prix_gplc                           1446 non-null   float64
#  20  prix_e10_mis_à_jour_le              7556 non-null   object
#  21  prix_e10                            7556 non-null   float64
#  22  prix_sp98_mis_à_jour_le             8112 non-null   object
#  23  prix_sp98                           8112 non-null   float64
#  24  début_rupture_e10_si_temporaire     2016 non-null   object
#  25  type_rupture_e10                    2016 non-null   object
#  26  début_rupture_sp98_si_temporaire    1587 non-null   object
#  27  type_rupture_sp98                   1587 non-null   object
#  28  début_rupture_sp95_si_temporaire    5602 non-null   object
#  29  type_rupture_sp95                   5602 non-null   object
#  30  début_rupture_e85_si_temporaire     4997 non-null   object
#  31  type_rupture_e85                    4997 non-null   object
#  32  début_rupture_gplc_si_temporaire    7149 non-null   object
#  33  type_rupture_gplc                   7149 non-null   object
#  34  début_rupture_gazole_si_temporaire  280 non-null    object
#  35  type_rupture_gazole                 280 non-null    object
#  36  carburants_disponibles              9675 non-null   object
#  37  carburants_indisponibles            9576 non-null   object
#  38  carburants_en_rupture_temporaire    1223 non-null   object
#  39  carburants_en_rupture_definitive    7838 non-null   object
#  40  automate_24-24_oui/non              10023 non-null  object
#  41  services_proposés                   9273 non-null   object
#  42  département                         10019 non-null  object
#  43  code_departement                    10019 non-null  object
#  44  région                              10019 non-null  object
#  45  code_region                         10019 non-null  float64
#  46  horaires_détaillés                  6299 non-null   object
# dtypes: float64(9), int64(2), object(36)
# memory usage: 3.6+ MB
#          id   latitude  longitude  code_postal pop                  adresse  \
# 0  21230005  4713100.0   449000.0        21230   R       Rue de l'Arquebuse
# 1  37210004  4741200.0    80300.0        37210   R        27 Rue des Écoles
# 2  46200004  4489900.0   147500.0        46200   R      51 rue de la Récège
# 3  33290001  4494839.0   -63068.0        33290   R        Route de Pauillac
# 4  12400003  4395400.0   285000.0        12400   R  Route de Saint-Affrique
#
#              ville                                           services  \
# 0     Arnay-le-Duc  {"service": ["Boutique alimentaire", "Boutique...
# 1          Vouvray  {"service": ["Laverie", "Relais colis", "Bouti...
# 2         Souillac  {"service": ["Laverie", "Relais colis", "Bouti...
# 3    Le Pian-Médoc  {"service": ["Toilettes publiques", "Boutique ...
# 4  Vabres-l'Abbaye  {"service": ["Toilettes publiques", "Laverie",...
#
#                                                 prix  \
# 0  [{"@nom": "Gazole", "@id": "1", "@maj": "2025-...
# 1  [{"@nom": "Gazole", "@id": "1", "@maj": "2025-...
# 2  [{"@nom": "Gazole", "@id": "1", "@maj": "2025-...
# 3  [{"@nom": "Gazole", "@id": "1", "@maj": "2025-...
# 4  [{"@nom": "Gazole", "@id": "1", "@maj": "2025-...
#
#                                              rupture  \
# 0  [{"@nom": "E85", "@id": "3", "@debut": "2024-1...
# 1  [{"@nom": "E85", "@id": "3", "@debut": "2022-1...
# 2  [{"@nom": "SP95", "@id": "2", "@debut": "2024-...
# 3  [{"@nom": "GPLc", "@id": "4", "@debut": "2017-...
# 4  [{"@nom": "GPLc", "@id": "4", "@debut": "2018-...
#
#                                             horaires                geom  \
# 0                                                NaN        47.131, 4.49
# 1  {"@automate-24-24": "1", "jour": [{"@id": "1",...       47.412, 0.803
# 2  {"@automate-24-24": "1", "jour": [{"@id": "1",...       44.899, 1.475
# 3                                                NaN  44.94839, -0.63068
# 4  {"@automate-24-24": "1", "jour": [{"@id": "1",...        43.954, 2.85
#
#    prix_gazole_mis_à_jour_le  prix_gazole    prix_sp95_mis_à_jour_le  \
# 0  2025-10-13T09:09:39+00:00        1.629  2025-10-13T09:09:39+00:00
# 1  2025-08-26T10:15:00+00:00        1.598  2025-08-26T10:15:00+00:00
# 2  2025-08-25T18:02:34+00:00        1.599                        NaN
# 3  2025-10-15T22:41:00+00:00        1.559                        NaN
# 4  2025-10-11T09:45:22+00:00        1.579  2025-10-11T09:45:22+00:00
#
#    prix_sp95     prix_e85_mis_à_jour_le  prix_e85 prix_gplc_mis_à_jour_le  \
# 0      1.729                        NaN       NaN                     NaN
# 1      1.756                        NaN       NaN                     NaN
# 2        NaN  2025-08-25T18:02:34+00:00     0.688                     NaN
# 3        NaN  2025-10-15T22:41:00+00:00     0.739                     NaN
# 4      1.719  2025-10-11T09:45:22+00:00     0.688                     NaN
#
#    prix_gplc     prix_e10_mis_à_jour_le  prix_e10    prix_sp98_mis_à_jour_le  \
# 0        NaN                        NaN       NaN  2025-10-13T09:09:39+00:00
# 1        NaN                        NaN       NaN  2025-08-26T10:15:00+00:00
# 2        NaN  2025-08-25T18:02:34+00:00     1.669                        NaN
# 3        NaN  2025-10-15T22:41:00+00:00     1.632  2025-10-15T22:41:00+00:00
# 4        NaN  2025-10-11T09:45:22+00:00     1.636                        NaN
#
#    prix_sp98 début_rupture_e10_si_temporaire type_rupture_e10  \
# 0      1.809       2019-10-25T15:45:03+00:00       definitive
# 1      1.767       2022-10-10T22:30:49+00:00       definitive
# 2        NaN                             NaN              NaN
# 3      1.735                             NaN              NaN
# 4        NaN                             NaN              NaN
#
#   début_rupture_sp98_si_temporaire type_rupture_sp98  \
# 0                              NaN               NaN
# 1                              NaN               NaN
# 2        2024-07-04T09:45:05+00:00        definitive
# 3                              NaN               NaN
# 4        2018-11-09T11:11:53+00:00        definitive
#
#   début_rupture_sp95_si_temporaire type_rupture_sp95  \
# 0                              NaN               NaN
# 1                              NaN               NaN
# 2        2024-07-04T09:45:05+00:00        definitive
# 3        2025-06-13T20:16:14+00:00        definitive
# 4                              NaN               NaN
#
#   début_rupture_e85_si_temporaire type_rupture_e85  \
# 0       2024-10-05T07:29:42+00:00       definitive
# 1       2022-10-10T22:30:49+00:00       definitive
# 2                             NaN              NaN
# 3                             NaN              NaN
# 4                             NaN              NaN
#
#   début_rupture_gplc_si_temporaire type_rupture_gplc  \
# 0        2024-10-05T07:30:13+00:00        definitive
# 1        2022-10-10T22:30:49+00:00        definitive
# 2        2025-01-03T14:44:47+00:00        definitive
# 3        2017-09-01T18:47:17+00:00        definitive
# 4        2018-11-09T11:11:53+00:00        definitive
#
#   début_rupture_gazole_si_temporaire type_rupture_gazole  \
# 0                                NaN                 NaN
# 1                                NaN                 NaN
# 2                                NaN                 NaN
# 3                                NaN                 NaN
# 4                                NaN                 NaN
#
#   carburants_disponibles carburants_indisponibles  \
# 0       Gazole,SP95,SP98             E85,GPLc,E10
# 1       Gazole,SP95,SP98             E85,GPLc,E10
# 2         Gazole,E85,E10           SP95,GPLc,SP98
# 3    Gazole,E85,E10,SP98                SP95,GPLc
# 4    Gazole,SP95,E85,E10                GPLc,SP98
#
#   carburants_en_rupture_temporaire carburants_en_rupture_definitive  \
# 0                              NaN                     E85;GPLc;E10
# 1                              NaN                     E85;GPLc;E10
# 2                              NaN                   SP95;GPLc;SP98
# 3                              NaN                        SP95;GPLc
# 4                              NaN                        GPLc;SP98
#
#   automate_24-24_oui/non                                  services_proposés  \
# 0                    Non  Boutique alimentaire,Boutique non alimentaire,...
# 1                    Oui  Laverie,Relais colis,Boutique alimentaire,Bout...
# 2                    Oui  Laverie,Relais colis,Boutique alimentaire,Bout...
# 3                    Non  Toilettes publiques,Boutique alimentaire,Bouti...
# 4                    Oui  Toilettes publiques,Laverie,Boutique alimentai...
#
#       département code_departement                   région  code_region  \
# 0       Côte-d'Or               21  Bourgogne-Franche-Comté         27.0
# 1  Indre-et-Loire               37      Centre-Val de Loire         24.0
# 2             Lot               46                Occitanie         76.0
# 3         Gironde               33       Nouvelle-Aquitaine         75.0
# 4         Aveyron               12                Occitanie         76.0
#
#                                   horaires_détaillés
# 0                                                NaN
# 1  Automate-24-24, Lundi 09.00-12.00 et 15.30-19....
# 2                                     Automate-24-24
# 3                                                NaN
# 4  Automate-24-24, Lundi00.00-23.59, Mardi00.00-2...

# %%
columns_to_keep = [ 'code_postal', 'prix_gazole', 'prix_sp95' , 'prix_e85', 'prix_gplc', 'prix_sp98' , 'prix_e10','carburants_disponibles', 'automate_24-24_oui/non']
Carburant = Carburant[columns_to_keep]
print(Carburant.head())
# Out:
#    code_postal  prix_gazole  prix_sp95  prix_e85  prix_gplc  prix_sp98  \
# 0        21230        1.629      1.729       NaN        NaN      1.809
# 1        37210        1.598      1.756       NaN        NaN      1.767
# 2        46200        1.599        NaN     0.688        NaN        NaN
# 3        33290        1.559        NaN     0.739        NaN      1.735
# 4        12400        1.579      1.719     0.688        NaN        NaN
#
#    prix_e10 carburants_disponibles automate_24-24_oui/non
# 0       NaN       Gazole,SP95,SP98                    Non
# 1       NaN       Gazole,SP95,SP98                    Oui
# 2     1.669         Gazole,E85,E10                    Oui
# 3     1.632    Gazole,E85,E10,SP98                    Non
# 4     1.636    Gazole,SP95,E85,E10                    Oui

# %%
import pandas as pd
import numpy as np

# %%
# Load the CSV
chunks = pd.read_csv('../Data/Carburant.csv', chunksize=1000000, low_memory=False, sep=";")

chunk_list = []
for chunk in chunks:
    print("Processing a new chunk...")
    df1 = pd.DataFrame(chunk)
    df1.columns = df1.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
    chunk_list.append(df1[['code_postal', 'prix_gazole', 'prix_sp95' , 'prix_e85', 'prix_gplc', 'prix_sp98' , 'prix_e10']])

# Concatenate all chunks into a single DataFrame
df = pd.concat(chunk_list, ignore_index=True)
mean = df.groupby("code_postal").mean().reset_index()
mean['totmean'] = mean[['prix_gazole', 'prix_sp95' , 'prix_e85', 'prix_sp98' , 'prix_e10']].where(mean[['prix_gazole', 'prix_sp95' , 'prix_e85', 'prix_sp98' , 'prix_e10']] > 0).mean(axis=1)
mean['code_postal'] = mean['code_postal'].apply(lambda row: str(row).zfill(5))

# Display basic information about the dataset
print(mean.info())
print(mean.sort_values(by="prix_gazole", ascending=False).head(10))
mean.to_csv('../DataCleaned/Carburant_Cleaned.csv', index=False)
# Out:
# Processing a new chunk...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4359 entries, 0 to 4358
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   code_postal  4359 non-null   object
#  1   prix_gazole  4319 non-null   float64
#  2   prix_sp95    2374 non-null   float64
#  3   prix_e85     2416 non-null   float64
#  4   prix_gplc    1070 non-null   float64
#  5   prix_sp98    3947 non-null   float64
#  6   prix_e10     3619 non-null   float64
#  7   totmean      4328 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 272.6+ KB
# None
#      code_postal  prix_gazole  prix_sp95  prix_e85  prix_gplc  prix_sp98  \
# 3964       85350       2.1300      2.258       NaN        NaN        NaN
# 3449       75001       2.0900      2.140       NaN        NaN     2.1900
# 3894       83990       1.9990        NaN       NaN        NaN     2.2850
# 3384       73450       1.9900      1.990       NaN        NaN     1.9900
# 3454       75011       1.9900      1.990       NaN        NaN        NaN
# 729        20150       1.9900      1.990       NaN        NaN        NaN
# 3451       75007       1.9805        NaN       NaN        NaN     2.1695
# 3457       75014       1.9575      2.450     0.803        NaN     2.1070
# 4211       92200       1.9390        NaN       NaN        NaN     2.1190
# 2320       54920       1.9300      1.940       NaN        NaN        NaN
#
#       prix_e10   totmean
# 3964       NaN  2.194000
# 3449       NaN  2.140000
# 3894    2.1590  2.147667
# 3384       NaN  1.990000
# 3454       NaN  1.990000
# 729        NaN  1.990000
# 3451    1.8290  1.993000
# 3457    1.8155  1.826600
# 4211       NaN  2.029000
# 2320       NaN  1.935000
